# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import sys
import os
import glob
from pathlib import Path
import numpy as np
import pandas as pd
import dask.dataframe as dd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker  # Import minor locator ticker
import matplotlib.colors as mcolors
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as patches
from re import split
from scipy.stats import skew

from scipy import stats
from scipy.stats import norm, gamma, logistic, t, lognorm, expon, betaprime
# from scipy.special import gamma

from scipy.optimize import curve_fit

import calendar

# from dask_jobqueue import SLURMCluster

# from dask.distributed import Client, progress
from IPython.display import Image
from dask.distributed import Client
import folium

import warnings

warnings.filterwarnings('ignore')

import seaborn as sns
# import hvplot.xarray

import Functions as Func

# %%
PROJECT_ROOT = Path.cwd().parent
DATA_PATH = PROJECT_ROOT / "data" / "resultados" / "Zarr"
FIG_PATH = PROJECT_ROOT / "figures"

instrument_path = FIG_PATH / "Samana"

instrument_path.mkdir(parents=True, exist_ok=True)


ds_1 = xr.open_zarr(
    DATA_PATH / "159_events.zarr"
)

pluvio = pd.read_csv(
    PROJECT_ROOT / "data" / "Pluviometricas_cercanas" / "Filtradas" / "Pluviometrica_60.csv"
)

# Filter
ds_1 = ds_1.dropna(dim="time", subset=["lwc_filt"])

# Disdro_name = 'Santa Rita Guatape'

ds_1
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:       (time: 509980, diameter: 22, velocity: 20)
# Coordinates:
#   * time          (time) datetime64[ns] 4MB 2015-10-10T23:47:31 ... 2025-04-2...
#   * diameter      (diameter) float64 176B 0.125 0.25 0.375 0.5 ... 7.0 7.5 8.0
#   * velocity      (velocity) float64 160B 0.1 0.2 0.4 0.6 ... 7.4 8.2 9.0 10.0
# Data variables: (12/19)
#     Client        (time) <U1 2MB dask.array<chunksize=(9993,), meta=np.ndarray>
#     MOR           (time) float64 4MB dask.array<chunksize=(9993,), meta=np.ndarray>
#     Synop_Code    (time) <U1 2MB dask.array<chunksize=(9993,), meta=np.ndarray>
#     d_m_filt      (time) float64 4MB dask.array<chunksize=(9993,), meta=np.ndarray>
#     lwc_filt      (time) float64 4MB dask.array<chunksize=(9993,), meta=np.ndarray>
#     n_t           (time) float64 4MB dask.array<chunksize=(9993,), meta=np.ndarray>
#     ...            ...
# ...

# %%
# Differences between bins
delta_D = ds_1.diameter.diff("diameter")  # length 21
# To leave it with length 22 like the original
delta_D = xr.concat([ds_1.diameter[0], delta_D], dim="diameter")

def M_n(diameter, nd, delta_D, n):
    return ((diameter ** n) * nd * delta_D).sum(dim='diameter')

def dist_parm(diameter, dm, delta_D, nd, M_0, M_2, M_3, M_4, M_6):
    eta = M_4 ** 2 / (M_2 * M_6)
    mu = ((7 - 11 * eta) - (eta ** 2 + 14 * eta + 1) ** 0.5) / 2 * (eta - 1)
    lambda_ = ((M_2 / M_4) * (mu + 3) * (mu + 4)) ** 0.5
    sigma_m = (((diameter - dm) ** 2 * nd *diameter ** 3 * delta_D).sum(dim='diameter') / M_3)
    N_0 = (M_0 * lambda_ ** (mu + 1)) / gamma(mu + 1)
    return eta, mu, lambda_, sigma_m, N_0

M_0 = M_n(ds_1.diameter, ds_1.nd_filt, delta_D, 0)
M_2 = M_n(ds_1.diameter, ds_1.nd_filt, delta_D, 2)
M_3 = M_n(ds_1.diameter, ds_1.nd_filt, delta_D, 3)
M_4 = M_n(ds_1.diameter, ds_1.nd_filt, delta_D, 4)
M_6 = M_n(ds_1.diameter, ds_1.nd_filt, delta_D, 6)

eta, mu, lambda_, sigma_m, N_0 = dist_parm(ds_1.diameter, ds_1.d_m_filt, delta_D, ds_1.nd_filt, M_0, M_2, M_3, M_4, M_6)

# %%
mask = ((~np.isnan(mu)) & (~np.isnan(lambda_)) & (mu != 0)).compute()
# mask = ((~np.isnan(mu)) & (~np.isnan(lambda_))).compute()
mu_mask = mu.where(mask, drop=True)
lambda_mask = lambda_.where(mask, drop=True)

plt.plot(lambda_, mu, 'o')
plt.show()

# Create 2D Histogram (Count Heatmap)
plt.figure(figsize=(8, 6))
hb = plt.hist2d(lambda_mask, mu_mask, bins=[50, 50], cmap='turbo', cmin=1)

# Add Color Bar
cb = plt.colorbar(hb[3])
cb.set_label('Conteo')

# %%
# Create figure with two subgraphs (vertical)
fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=False)

# --- Subgraph 1: Histogram of D_0 ---
sns.histplot(ds_1.d_m_filt, bins=22, stat="probability", ax=axs[0], color='tab:blue', label='$D_m\ [mm]$')
# axs[0].set_title(f'{Disdro_name}')
axs[0].set_ylabel('PDF', color='tab:blue')
axs[0].tick_params(axis='y', labelcolor='tab:blue')
axs[0].set_xlim(0, 5.5)
axs[0].set_xticks(np.arange(0, 5.5, 0.5))
axs[0].legend(loc=(0.8, 0.78))

# Create twin axis for n_w_filt
ax2 = axs[0].twinx()

# Histogram of n_w_filt with right axis
sns.histplot(np.log10(ds_1.n_w_filt), bins=22, stat="probability", ax=ax2, label='$log_{10}(N_w)\ [mm^{-1}m^{-3}]$', color='tab:red', alpha=0.6)
ax2.set_ylabel('PDF', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

ax2.legend(loc='upper right')

# Show legend and graph
fig.tight_layout()

# --- Subgraph 2: Histogram of Nw ---
sns.histplot(ds_1.lwc_filt, bins=15, stat="probability", ax=axs[1], color='tab:red', label='$LWC\ [g/m^3]$')
# axs[1].set_title('Distribución de $N_w$')
# axs[1].set_xlabel('$N_w\ [mm^{-3} mm^{-1}]$')
axs[1].set_ylabel('')
axs[1].set_yscale('log')
# axs[1].set_xticks(np.arange(0, 5.5, 0.5))
axs[1].legend()

# Adjust spaces
plt.tight_layout()

plt.show()

# %%
print('Dm:', ds_1.d_m_filt.mean().values, ds_1.d_m_filt.std().values, skew(ds_1.d_m_filt.values, nan_policy='omit'))
print('log10(Nw):', np.log10(ds_1.n_w_filt).mean().values, np.log10(ds_1.n_w_filt).std().values, skew(np.log10(ds_1.n_w_filt).values, nan_policy='omit'))
print('W:', ds_1.lwc_filt.mean().values, ds_1.lwc_filt.std().values, skew(ds_1.lwc_filt.values, nan_policy='omit'))
# Out:
# Dm: 1.172359562627086 0.6253525411024611 1.6072402546803932
# log10(Nw): 3.427518922060367 0.6696636029813919 -0.4818112284756711
# W: 0.2470163467141037 0.6305536700101205 4.808922190269845

# %%
# Extraer los datos (asegúrate de que no haya NaNs)
data = np.log10(ds_1.n_w_filt.values)
data = data[~np.isnan(data)]

# Lista de distribuciones a probar
distributions = {
    "Normal": stats.norm,
    "Gamma": stats.gamma,
    "Logística": stats.logistic,
    # "Student-t": stats.t
}

results = {}
n = len(data)

for name, dist in distributions.items():
    # Ajustar distribución
    params = dist.fit(data, loc=0.25)

    # Log-verosimilitud
    loglik = np.sum(dist.logpdf(data, *params))
    k = len(params)

    # AIC y BIC
    aic = 2*k - 2*loglik
    bic = k*np.log(n) - 2*loglik

    # KS test (estadístico y p-valor)
    ks_stat, ks_pval = stats.kstest(data, dist.cdf, args=params)

    results[name] = {
        "params": params,
        "loglik": loglik,
        "AIC": aic,
        "BIC": bic,
        "KS_stat": ks_stat,
        "KS_pval": ks_pval
    }

# Resultados en DataFrame
df_results = pd.DataFrame(results).T
print(df_results)

# --- Anderson-Darling solo funciona para Normal, Exponencial y Logistic ---
try:
    ad_stat, crit_vals, sig_levels = stats.anderson(data, dist='norm')
    print("\nAnderson-Darling (Normal):")
    print(f"Estadístico: {ad_stat}")
    for sl, cv in zip(sig_levels, crit_vals):
        print(f"  Nivel {sl}%: Crítico = {cv}")
except Exception as e:
    print("Error en Anderson-Darling:", e)

# Graficar histogramas + curvas ajustadas
x = np.linspace(min(data), max(data), 1000)
plt.hist(data, bins=22, density=True, alpha=0.6, color="red", label="Datos")

for name, dist in distributions.items():
    params = results[name]["params"]
    pdf = dist.pdf(x, *params)
    plt.plot(x, pdf, label=name)

plt.xlabel("n_w_filt")
plt.ylabel("Densidad")
plt.legend()
plt.title("Ajuste de distribuciones a n_w_filt")
plt.show()
# Out:
#                                                       params         loglik  \
# Normal              (3.2839532989111984, 0.5861536757724372) -457251.992254
# Gamma      (162.46348058784235, -4.442173378418522, 0.047... -465279.690439
# Logística            (3.311895339946961, 0.3275267084235082)  -454867.30151
#
#                      AIC            BIC   KS_stat KS_pval
# Normal     914507.984508  914530.295354  0.045585     0.0
# Gamma      930565.380878  930598.847146  0.057432     0.0
# Logística   909738.60302  909760.913865  0.022686     0.0
#
# Anderson-Darling (Normal):
# Estadístico: 1995.2411779994145
#   Nivel 15.0%: Crítico = 0.561
#   Nivel 10.0%: Crítico = 0.631
#   Nivel 5.0%: Crítico = 0.752
#   Nivel 2.5%: Crítico = 0.873
#   Nivel 1.0%: Crítico = 1.035

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import rv_continuous

# --- Datos ---
data_1 = ds_1.d_m_filt.values
data_1 = data_1[~np.isnan(data_1)]

# --- Límites físicos del disdrómetro ---
a, b = 0.25, 8.0

# --- Función para crear una versión truncada de cualquier distribución ---
def get_truncated(dist, a, b, params):
    # Convertir los límites con los parámetros ajustados
    Fa, Fb = dist.cdf([a, b], *params)

    def cdf(x):
        return (dist.cdf(x, *params) - Fa) / (Fb - Fa)

    def pdf(x):
        return dist.pdf(x, *params) / (Fb - Fa)

    return pdf, cdf

# --- Distribuciones a probar ---
distributions = {
    "Gamma": stats.gamma,
    "Lognormal": stats.lognorm,
    "Betaprime": stats.betaprime
}

results = {}
n = len(data_1)

for name, dist in distributions.items():
    # Ajuste inicial
    params = dist.fit(data_1, floc=a)

    # Crear versión truncada con los parámetros ya ajustados
    pdf, cdf = get_truncated(dist, a, b, params)

    # Log-verosimilitud
    loglik = np.sum(np.log(pdf(data_1)))
    k = len(params)

    # AIC y BIC
    aic = 2*k - 2*loglik
    bic = k*np.log(n) - 2*loglik

    # KS test con la CDF truncada
    ks_stat, ks_pval = stats.kstest(data_1, cdf)

    results[name] = {
        "params": params,
        "loglik": loglik,
        "AIC": aic,
        "BIC": bic,
        "KS_stat": ks_stat,
        "KS_pval": ks_pval
    }

# Resultados en DataFrame
df_results = pd.DataFrame(results).T
print(df_results)

# --- Graficar histogramas + curvas ajustadas ---
x = np.linspace(min(data_1), max(data_1), 1000)
plt.hist(data_1, bins=22, density=True, alpha=0.6, color="blue", label="Datos")

for name, dist in distributions.items():
    params = results[name]["params"]
    pdf, _ = get_truncated(dist, a, b, params)  # <-- ahora pasamos params
    plt.plot(x, pdf(x), label=name + " truncada")

plt.xlabel("$D_m$")
plt.ylabel("Densidad")
plt.legend()
plt.xlim(0, 8)
plt.title("Ajuste de distribuciones truncadas a $D_m$")
plt.show()
# Out:
#                                                       params         loglik  \
# Gamma        (3.0768747557026526, 0.25, 0.26841575134891477) -283345.689494
# Lognormal     (0.6097221484138697, 0.25, 0.6959204175654558) -290252.746527
# Betaprime  (3.397411002921875, 30.695233744850377, 0.25, ... -282549.770066
#
#                      AIC            BIC   KS_stat KS_pval
# Gamma      566697.378987  566730.845256  0.024101     0.0
# Lognormal  580511.493055  580544.959323  0.060259     0.0
# Betaprime  565107.540131  565152.161822  0.032015     0.0

# %%
params
# Out:
# (np.float64(3.397411002921875),
#  np.float64(30.695233744850377),
#  0.25,
#  np.float64(7.217630113759206))

# %%
# Parámetros distribuciones log10(Nw)
mu, sigma = 3.18589097714578, 0.6522654180681844   # Normal
gamma_params = 169.31315130200778, -5.416447716254519, 0.050 # shape, loc, scale
# gamma_params = gamma.fit(data, floc=0.25) # shape, loc, scale 
logistic_params = (3.1963145400463406, 0.3748533551907958) # loc, scale
# t_params = (68058742588.37283, 3.311684203262347, 0.66929) # df, loc, scale

# Parámetros distribuciones Dm
gamma_params_Dm = 1.8034087813120083, 0.25, 0.3881677308617781 # shape σ, loc, scale θ
Lognorm_params_Dm = 0.803717640603716, 0.25, 0.517463049347576 # shape σ, loc, scale θ
betaprime_params_Dm = params # Shape α, Shape β,loc, scaleθ

# Crear rango de valores para evaluar las densidades
x = np.linspace(0.25, 8, 2000)
x_1 = np.linspace(0.25, 8, 70)

_, edges_dm = np.histogram(data_1, bins=22)
dx = edges_dm[1] - edges_dm[0]  # ancho del bin

_, edges_Nw = np.histogram(data, bins=22)
dy = edges_Nw[1] - edges_Nw[0]  # ancho del bin

bin_width_Dm = dx
bin_width_Nw = dy

# Calcular PDFs de cada distribución log10(Nw)
pdf_normal = norm.pdf(x_1, mu, sigma) * bin_width_Nw
pdf_gamma = gamma.pdf(x, *gamma_params) * bin_width_Nw
pdf_logistic = logistic.pdf(x, *logistic_params) * bin_width_Nw
# pdf_t = t.pdf(x, *t_params)

# Dm distribución
pdf_gamma_Dm = gamma.pdf(x, *gamma_params_Dm) * bin_width_Dm
pdf_Lognorm_Dm = lognorm.pdf(x, *Lognorm_params_Dm) * bin_width_Dm
pdf_betaprime_Dm = betaprime.pdf(x, *betaprime_params_Dm) * bin_width_Dm

# Create figure with two subgraphs (vertical)
fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=False)

# --- Subgraph 1: Histogram of D_0 ---
sns.histplot(ds_1.d_m_filt, bins=22, stat="probability", ax=axs[0], color='tab:blue', label='$D_m\ [mm]$')
axs[0].plot(x, pdf_gamma_Dm, label="Gamma", color='blue')
axs[0].plot(x, pdf_Lognorm_Dm, label="Lognormal", color='orange')
axs[0].plot(x, pdf_betaprime_Dm, label="Betaprime", color='green')
# axs[0].set_title(f'{Disdro_name}')
axs[0].set_ylabel('PDF', color='tab:blue')
axs[0].tick_params(axis='y', labelcolor='tab:blue')
axs[0].set_xlim(0, 5.5)
axs[0].set_xticks(np.arange(0, 5.5, 0.5))

# ---- Agregar divisiones menores en ejes ----
axs[0].yaxis.set_minor_locator(ticker.AutoMinorLocator())
axs[0].xaxis.set_minor_locator(ticker.AutoMinorLocator())

# Create twin axis for n_w_filt
ax2 = axs[0].twinx()

# Histogram of n_w_filt with right axis

# Curvas ajustadas
plt.plot(x_1, pdf_normal, label="Normal", color='red', marker='s', linestyle='-')
plt.plot(x, pdf_gamma, label="Gamma", color='purple')
plt.plot(x, pdf_logistic, label="Logística", color='brown')
# plt.plot(x, pdf_t, label="Student-t", color='red')

sns.histplot(data, bins=22, stat="probability", ax=ax2, label='$log_{10}(N_w)\ [mm^{-1}m^{-3}]$', color='tab:red', alpha=0.6)
ax2.set_ylabel('PDF', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

ax2.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax2.xaxis.set_minor_locator(ticker.AutoMinorLocator())

# ax2.legend(loc='upper right')

# Show legend and graph
fig.tight_layout()

# --- Subgraph 2: Histogram of Nw ---
sns.histplot(ds_1.lwc_filt, bins=15, stat="probability", ax=axs[1], color='tab:green', label='$LWC\ [g/m^3]$', alpha=0.6)
# axs[1].set_title('Distribución de $N_w$')
# axs[1].set_xlabel('$N_w\ [mm^{-3} mm^{-1}]$')
axs[1].set_ylabel('PDF')
axs[1].set_yscale('log')
# axs[1].set_xticks(np.arange(0, 5.5, 0.5))
# axs[1].legend()
plt.gca().yaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.gca().xaxis.set_minor_locator(ticker.AutoMinorLocator())

# Adjust spaces
plt.tight_layout()

# Unir leyendas de axs[0] y ax2 en una sola
handles1, labels1 = axs[0].get_legend_handles_labels()  # hist + curvas Dm
handles2, labels2 = ax2.get_legend_handles_labels()     # hist + curvas log10(Nw)
handles3, labels3 = axs[1].get_legend_handles_labels()  # hist LWC

# Combinar todo
handles = handles1 + handles2 + handles3
labels = labels1 + labels2 + labels3

# Diccionario de prioridades
priority = {
    "$D_m\\ [mm]$": 0,
    "$log_{10}(N_w)\\ [mm^{-1}m^{-3}]$": 1,
    "$LWC\\ [g/m^3]$": 2,
    "Gamma": 3,
    "Lognormal": 4,
    "Betaprime": 5,
    "Normal": 6,
    "Logística": 7
    # "Student-t": 8
}

# Reordenar según prioridad
order = sorted(range(len(labels)), key=lambda i: priority.get(labels[i], 999))
handles = [handles[i] for i in order]
labels = [labels[i] for i in order]

# Dibujar leyenda
# axs[0].legend(
#     handles, labels,
#     loc='upper left',
#     bbox_to_anchor=(1.12, 1),
#     borderaxespad=0.,
#     frameon=True
# )

plt.savefig(instrument_path / "Montañita_San_Antonio_Decembers.png", 
            dpi=300, 
            bbox_inches='tight')
plt.show()

# %%
params_dict = {
    "Torre SIATA": {
        "Dm": {
            "Gamma": (2.0263356114116213, 0.25, 0.3407304341815894),
            "Lognormal": (0.7663964588996769, 0.25, 0.5288591100502392),
            "Betaprime": (2.372971112979548, 7.082785502830802, 0.25, 1.7998754635712282)
        },
        "log10Nw": {
            "Gamma": (163.87745491733534, -4.81562565226937, 0.0484),
            "Normal": (3.129564388859826, 0.614961117077337),
            "Logistic": (3.141275295743291, 0.3550843093221234)
        }
    },
    "Parque 3 Aguas": {
        "Dm": {
            "Gamma": (1.9169137691743525, 0.25, 0.3339648185159577),
            "Lognormal": (0.7755872527748382, 0.25, 0.4824083403792065),
            "Betaprime": (2.5548125959282126, 7.263481323750701, 0.25, 1.5742745284607218)
        },
        "log10Nw": {
            "Gamma": (177.34548125645955, -5.668524140560335, 0.050),
            "Normal": (3.228795034209086, 0.6630521659764125),
            "Logistic": (3.24380942154393, 0.38297933814391366)
        }
    },
    "Santa Rita Guatapé": {
        "Dm": {
            "Gamma": (1.8117948995519313, 0.25, 0.40361508840148724),
            "Lognormal": (0.8126190790001143, 0.25, 0.5413734832915853),
            "Betaprime": (2.0166353366407117, 15.92676115571704, 0.25, 5.415013867689215)
        },
        "log10Nw": {
            "Gamma": (186.14994424566407, -6.017639076400364, 0.050),
            "Normal": (3.311683817895669, 0.6692970732845354),
            "Logistic": (3.336173848271336, 0.3879206924517812)
        }
    },
    "Samaná": {
        "Dm": {
            "Gamma": (1.676936106132245, 0.25, 0.4670760471402866),
            "Lognormal": (0.8493199964276668, 0.25, 0.56486254084112),
            "Betaprime": (1.890526118376488, 13.208071629193803, 0.25, 5.061568365669331)
        },
        "log10Nw": {
            "Gamma": (158.37207825451924, -5.697554043528811, 0.056),
            "Normal": (3.2653409493116126, 0.7051167642955097),
            "Logistic": (3.28294635098617, 0.40786505792712624)
        }
    },
    "La Estrella": {
        "Dm": {
            "Gamma": (1.9939536658787018, 0.25, 0.35558325992275613),
            "Lognormal": (0.7699360343081277, 0.25, 0.54057688242527),
            "Betaprime": (2.2709135701902694, 14.952544287513623, 0.25, 4.3571371358110245)
        },
        "log10Nw": {
            "Gamma": (177.44951713479452, -5.444300026139535, 0.048),
            "Normal": (3.157742124433746, 0.6335263483184765),
            "Logistic": (3.171916782115611, 0.3647336967762955)
        }
    },
    "Puerto Triunfo": {
        "Dm": {
            "Gamma": (2.1710263881860907, 0.25, 0.3471476783437744),
            "Lognormal": (0.7473893147795311, 0.25, 0.5883416166903761),
            "Betaprime": (2.1811007466709977, 410.5441152493181, 0.25, 141.51556780195642)
        },
        "log10Nw": {
            "Gamma": (163.53120251886583, -4.728873023339233, 0.047),
            "Normal": (3.116580257928311, 0.6050682123686896),
            "Logistic": (3.1306928075621636, 0.34952904022710907)
        }
    },
    "Radar de Vientos": {
        "Dm": {
            "Gamma": (2.0750260700649017, 0.25, 0.3190376297371184),
            "Lognormal": (0.7488447374719919, 0.25, 0.5104928015389245),
            "Betaprime": (2.4799154710655036, 11.872611135848302, 0.25, 2.9034237500174394)
        },
        "log10Nw": {
            "Gamma": (149.04495698746956, -4.774272494084018, 0.053),
            "Normal": (3.194268525769403, 0.6413939451640395),
            "Logistic": (3.212945193328693, 0.36985780377520594)
        }
    },
    "Montañita San Antonio": {
        "Dm": {
            "Gamma": (1.8034087813120083, 0.25, 0.3881677308617781),
            "Lognormal": (0.803717640603716, 0.25, 0.517463049347576),
            "Betaprime": (2.372971112979548, 7.082785502830802, 0.25, 1.7998754635712282)
        },
        "log10Nw": {
            "Gamma": (169.31315130200778, -5.416447716254519, 0.050),
            "Normal": (3.18589097714578, 0.6522654180681844),
            "Logistic": (3.1963145400463406, 0.3748533551907958)
        }
    }
}

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# --- Definir truncamiento ---
a, b = 0.25, 8  # límites inferior y superior

def get_truncated(dist, a, b, params):
    """
    Retorna funciones PDF, CDF y PPF truncadas de una distribución.
    """
    def cdf(x):
        return (dist.cdf(x, *params) - dist.cdf(a, *params)) / (
            dist.cdf(b, *params) - dist.cdf(a, *params)
        )
    
    def ppf(q):
        # cuantil truncado
        return dist.ppf(
            dist.cdf(a, *params) + q * (dist.cdf(b, *params) - dist.cdf(a, *params)),
            *params,
        )
    
    def pdf(x):
        return dist.pdf(x, *params) / (
            dist.cdf(b, *params) - dist.cdf(a, *params)
        )
    
    return pdf, cdf, ppf


# --- Cuantiles empíricos ---
data_sorted = np.sort(data_1)
n = len(data_sorted)
emp_q = (np.arange(1, n+1) - 0.5) / n  # probabilidad empírica
emp_quantiles = np.quantile(data_1, emp_q)

plt.figure(figsize=(8,6))

# Dibujar los puntos de los datos (comunes a todas las distribuciones)
plt.plot(emp_quantiles, data_sorted, "o", color="black", alpha=0.4, label="Datos empíricos")

# Dibujar los ajustes truncados de cada distribución
for name, dist in distributions.items():
    params = results[name]["params"]
    
    # Crear versión truncada
    pdf, cdf, ppf = get_truncated(dist, a, b, params)
    
    # Cuantiles teóricos truncados
    theo_quantiles = ppf(emp_q)
    
    # Línea de ajuste
    plt.plot(theo_quantiles, data_sorted, label=name + " truncada")

# Línea 45°
lim_min = min(data_sorted.min(), theo_quantiles.min())
lim_max = max(data_sorted.max(), theo_quantiles.max())
plt.plot([lim_min, lim_max], [lim_min, lim_max], "k--", lw=1)

plt.xlabel("$Q_{Teo}$")
plt.ylabel("$Q_{exp}$")
plt.title("QQ-plot comparativo de distribuciones truncadas")
plt.legend()
# plt.grid(True, ls="--", alpha=0.6)
plt.gca().yaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.gca().xaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.legend(bbox_to_anchor=(1.00, 1), loc='upper left')

plt.show()

# %%
# Torre_SIATA = power_law(dm_range_1, 141.30, 6.72)
# P_3_Aguas = power_law(dm_range_1, 128.10, 6.82)
# S_Rita_Guatape = power_law(dm_range, 177.6, 7.26)
# Samana = power_law(dm_range, 136.2, 7.54)
# La_Estrella = power_law(dm_range, 106.9, 6.23)
# Puerto_Triunfo = power_law(dm_range, 116.33, 6.86)
# Radar_Vientos = power_law(dm_range, 81.8, 6.26)
# Montañita_SanAntonio = power_law(dm_range, 142.50, 6.74)
# Williams = power_law(dm_range_1, 194, 5.71)

# %%
def power_law(dm):
    return 141.30 * dm ** 6.72

# Curve Fitting
dm_range = np.linspace(0.1, 8, 100)
z_model = power_law(dm_range)

ref_data = 10 * np.log10(ds_1.ref_filt)

ref_model = 10 * np.log10(z_model)

mask = ((~np.isnan(ds_1.d_m_filt)) & (~np.isnan(ref_data)) & (ref_data > 0)).compute()

# Apply Mask
dm = ds_1.d_m_filt.where(mask, drop=True)
z_dbz = ref_data.where(mask, drop=True)

# Create 2D Histogram (Count Heatmap)
plt.figure(figsize=(8, 6))
hb = plt.hist2d(dm, z_dbz, bins=[50, 50], cmap='turbo', cmin=1)

plt.plot(dm_range, ref_model, color='black', linestyle='-', label='$Z\ [mm^6m^{-3}]=141.30 D_m^{6.72}$', linewidth=2)

# Add Color Bar
cb = plt.colorbar(hb[3])
# cb.set_label('Conteo', fontsize=14)
cb.ax.tick_params(labelsize=14)

# Labels and Title
plt.xlabel('$D_m\ [mm]$', fontsize=14)
plt.ylabel('$Z\ [dBZ]$', fontsize=14)
# plt.title('Reflectividad vs Diámetro medio')

# Optional: Adjust Axis Limits
plt.xlim(0, 8)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.ylim(10, 60)
plt.legend(
    loc='lower right',
    fontsize=14,
    frameon=True,         # Make it Boxed
    framealpha=0.9,       # Box Transparency
    edgecolor='black'     # Border Color
)
plt.gca().yaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.gca().xaxis.set_minor_locator(ticker.AutoMinorLocator())

plt.tight_layout()
# plt.savefig(instrument_path / "Torre_SIATA_Dm_Z.png", 
#             dpi=300, 
#             bbox_inches='tight')
plt.show()

# %%
# Torre_SIATA = power_law(dm_range, 0.49, 4.39)
# P_3_Aguas = power_law(dm_range, 0.77, 3.95)
# S_Rita_Guatape = power_law(dm_range, 1.04, 4.21)
# Samana = power_law(dm_range, 0.85, 4.41)
# La_Estrella = power_law(dm_range, 0.43, 4.60)
# Puerto_Triunfo = power_law(dm_range, 0.35, 4.20)
# Radar_Vientos = power_law(dm_range, 0.52, 4.28)
# Montañita_SanAntonio = power_law(dm_range, 0.47, 4.36)
# Williams = power_law(dm_range, 1.15, 3.14)

# %%
def power_law(dm):
    return 0.49 * dm ** 4.39

# Curve Fitting
dm_range = np.linspace(0.1, 8, 100)
r_model = power_law(dm_range)

rain_model = 10 * np.log10(r_model)

# Convert R (rainfall intensity) to logarithmic scale
r_dbr = 10 * np.log10(ds_1.r_int_filt)

# Create valid mask: no NaNs and only R > 0
mask = (
    (~np.isnan(ds_1.d_m_filt)) &
    (~np.isnan(r_dbr)) &
    (ds_1.r_int_filt > 0) &
    (r_dbr > -10)
).compute()

# Apply Mask
dm = ds_1.d_m_filt.where(mask, drop=True)
r_dbr = r_dbr.where(mask, drop=True)

# Create 2D Histogram: Dm vs dBR
plt.figure(figsize=(8, 6))
hb = plt.hist2d(dm, r_dbr, bins=[50, 50], cmap='turbo', cmin=1)

plt.plot(dm_range, rain_model, color='black', linestyle='-', label='$R\ [mm h^{-1}]=0.49 D_m^{4.39}$', linewidth=2)

# Color Bar (Count)
cb = plt.colorbar(hb[3])
cb.set_label('Conteo', fontsize=14)
cb.ax.tick_params(labelsize=14)

# Labels and Title
plt.xlabel('$D_m\ [mm]$', fontsize=14)
plt.ylabel('$10log(R)\ [dBR]$', fontsize=14)
# plt.title('Relación $D_m$ vs $R$')

# Axis Settings
plt.xlim(0, 8)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.ylim(0, 60)  # You can customize according to your data range
plt.legend(
    loc='lower right',
    fontsize=14,
    frameon=True,         # To have a box
    framealpha=0.9,       # Box transparency
    edgecolor='black'     # Border color
)
plt.gca().yaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.gca().xaxis.set_minor_locator(ticker.AutoMinorLocator())

plt.tight_layout()
# plt.savefig(instrument_path / "Torre_SIATA_Dm_R.png", 
#             dpi=300, 
#             bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# --- 1. Prepare data ---
ref_data = 10 * np.log10(ds_1.ref_filt)

# Valid data mask
mask = ((~np.isnan(ds_1.d_m_filt)) & (~np.isnan(ref_data)) & (ref_data > 0)).compute()
dm = ds_1.d_m_filt.where(mask, drop=True).values
z_dbz = ref_data.where(mask, drop=True).values

# --- 2. Build 2D histogram ---
bins_dm = np.linspace(0, 8, 50)
bins_z  = np.linspace(0, 60, 50)
H, xedges, yedges = np.histogram2d(dm, z_dbz, bins=[bins_dm, bins_z])

# --- 3. Find ridge with filtering ---
min_count = 2000  # Minimum number of points per bin to include
crest_dm = []
crest_z  = []

for i in range(len(xedges)-1):
    col = H[i, :]
    total_count = np.sum(col)
    if total_count >= min_count:  # Only bins with sufficient count
        j_max = np.argmax(col)
        dm_center = 0.5 * (xedges[i] + xedges[i+1])
        z_center  = 0.5 * (yedges[j_max] + yedges[j_max+1])
        crest_dm.append(dm_center)
        crest_z.append(z_center)

crest_dm = np.array(crest_dm)
crest_z = np.array(crest_z)

# --- 4. Convert Z_dBZ to linear Z ---
crest_z_lin = 10 ** (crest_z / 10)

# --- 5. Model fit ---
def power_law(Dm, alpha, beta):
    return alpha * Dm**beta

popt, pcov = curve_fit(power_law, crest_dm, crest_z_lin, p0=[200, 5])
alpha_fit, beta_fit = popt
print(f"alpha = {alpha_fit:.2f}, beta = {beta_fit:.2f}")

# --- 6. Curve fit ---
dm_range = np.linspace(0.1, 8, 200)
z_fit_lin = power_law(dm_range, alpha_fit, beta_fit)
z_fit_dbz = 10 * np.log10(z_fit_lin)

# --- 7. Plot ---
plt.figure(figsize=(8, 6))
plt.hist2d(dm, z_dbz, bins=[bins_dm, bins_z], cmap='turbo', cmin=1)
plt.plot(dm_range, z_fit_dbz, 'k-', linewidth=2,
         label=f'$Z = {alpha_fit:.1f} D_m^{{{beta_fit:.2f}}}$')
plt.scatter(crest_dm, crest_z, color='pink', s=15, label='Cresta')

cb = plt.colorbar()
cb.set_label('Conteo')

plt.xlabel('$D_m$ [mm]')
plt.ylabel('$Z$ [dBZ]')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# alpha = 142.53, beta = 6.74

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# --- 1. Prepare data ---
r_dbr = 10 * np.log10(ds_1.r_int_filt)

# Mask valid data
mask = (
    (~np.isnan(ds_1.d_m_filt)) &
    (~np.isnan(r_dbr)) &
    (r_dbr > -10)
).compute()

dm = ds_1.d_m_filt.where(mask, drop=True).values
r_dbr = r_dbr.where(mask, drop=True).values

# --- 2. Construct 2D histogram ---
bins_dm = np.linspace(0, 8, 50)
bins_r  = np.linspace(-10, 25, 50)  # rango para R en dBR
H, xedges, yedges = np.histogram2d(dm, r_dbr, bins=[bins_dm, bins_r])

# --- 3. Find ridge ---
min_count = 1300
crest_dm = []
crest_r  = []

for i in range(len(xedges)-1):
    col = H[i, :]
    total_count = np.sum(col)
    if total_count >= min_count:
        j_max = np.argmax(col)
        dm_center = 0.5 * (xedges[i] + xedges[i+1])
        r_center  = 0.5 * (yedges[j_max] + yedges[j_max+1])
        crest_dm.append(dm_center)
        crest_r.append(r_center)

crest_dm = np.array(crest_dm)
crest_r = np.array(crest_r)

# --- 4. Convert R_dBR to linear R ---
crest_r_lin = 10 ** (crest_r / 10)

# --- 5. Fit model ---
def power_law(Dm, alpha, beta):
    return alpha * Dm**beta

popt, pcov = curve_fit(power_law, crest_dm, crest_r_lin, p0=[1, 1])
alpha_fit, beta_fit = popt
print(f"alpha = {alpha_fit:.3f}, beta = {beta_fit:.3f}")

# --- 6. Fit curve ---
dm_range = np.linspace(0.1, 8, 200)
r_fit_lin = power_law(dm_range, alpha_fit, beta_fit)
r_fit_dbr = 10 * np.log10(r_fit_lin)

# --- 7. Plot ---
plt.figure(figsize=(8, 6))
plt.hist2d(dm, r_dbr, bins=[bins_dm, bins_r], cmap='turbo', cmin=1)
plt.plot(dm_range, r_fit_dbr, 'k-', linewidth=2,
         label=f'$R = {alpha_fit:.2f} D_m^{{{beta_fit:.2f}}}$')
plt.scatter(crest_dm, crest_r, color='pink', s=15, label='Cresta')

cb = plt.colorbar()
cb.set_label('Conteo')

plt.xlabel('$D_m$ [mm]')
plt.ylabel('$10 \log_{10}(R)$ [dBR]')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# alpha = 0.471, beta = 4.363

# %%
def power_law(dm, a, b):
    return a * dm ** b

dm_range = np.linspace(0.1, 8, 1000)
dm_range_1 = np.linspace(0.1, 8, 100)

Torre_SIATA = power_law(dm_range_1, 141.30, 6.72)
P_3_Aguas = power_law(dm_range_1, 128.10, 6.82)
S_Rita_Guatape = power_law(dm_range, 177.6, 7.26)
Samana = power_law(dm_range, 136.2, 7.54)
La_Estrella = power_law(dm_range, 106.9, 6.23)
Puerto_Triunfo = power_law(dm_range, 116.33, 6.86)
Radar_Vientos = power_law(dm_range, 81.8, 6.26)
Montañita_SanAntonio = power_law(dm_range, 142.50, 6.74)
Williams = power_law(dm_range_1, 194, 5.71)

Torre_SIATA_model = 10 * np.log10(Torre_SIATA)
P_3_Aguas_model = 10 * np.log10(P_3_Aguas)
S_Rita_Guatape_model = 10 * np.log10(S_Rita_Guatape)
Samana_model = 10 * np.log10(Samana)
La_Estrella_model = 10 * np.log10(La_Estrella)
Puerto_Triunfo_model = 10 * np.log10(Puerto_Triunfo)
Radar_Vientos_model = 10 * np.log10(Radar_Vientos)
Montañita_SanAntonio_model = 10 * np.log10(Montañita_SanAntonio)
Williams_model = 10 * np.log10(Williams)

plt.figure(figsize=(8, 6))

plt.plot(dm_range_1, Torre_SIATA_model, label='Torre SIATA', color='blue', alpha=0.3, marker='o', linestyle='-', lw=6)
plt.plot(dm_range_1, P_3_Aguas_model, label='Parque 3 Aguas', color='red', alpha=0.3, marker='s', linestyle='-')
plt.plot(dm_range, S_Rita_Guatape_model, label='Santa Rita Guatapé', color='green')
plt.plot(dm_range, Samana_model, label='Samaná', color='orange')
plt.plot(dm_range, La_Estrella_model, label='La Estrella', color='purple')
plt.plot(dm_range, Puerto_Triunfo_model, label='Puerto Triunfo', color='brown')
plt.plot(dm_range, Radar_Vientos_model, label='Radar de Vientos', color='cyan')
plt.plot(dm_range, Montañita_SanAntonio_model, label='Montañita San Antonio', color='gray')
plt.plot(dm_range_1, Williams_model, '^', label='Williams', color='black', alpha=0.3)

plt.xlabel('$D_m\ [mm]$')
plt.ylabel('$Z\ [dBZ]$')
plt.gca().yaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.gca().xaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.ylim(0, 60)
plt.xlim(0, 4.7)

plt.show()

# %%
def power_law(dm, a, b):
    return a * dm ** b

dm_range = np.linspace(0.1, 8, 100)

Torre_SIATA = power_law(dm_range, 0.49, 4.39)
P_3_Aguas = power_law(dm_range, 0.77, 3.95)
S_Rita_Guatape = power_law(dm_range, 1.04, 4.21)
Samana = power_law(dm_range, 0.85, 4.41)
La_Estrella = power_law(dm_range, 0.43, 4.60)
Puerto_Triunfo = power_law(dm_range, 0.35, 4.20)
Radar_Vientos = power_law(dm_range, 0.52, 4.28)
Montañita_SanAntonio = power_law(dm_range, 0.47, 4.36)
Williams = power_law(dm_range, 1.15, 3.14)

Torre_SIATA_model = 10 * np.log10(Torre_SIATA)
P_3_Aguas_model = 10 * np.log10(P_3_Aguas)
S_Rita_Guatape_model = 10 * np.log10(S_Rita_Guatape)
Samana_model = 10 * np.log10(Samana)
La_Estrella_model = 10 * np.log10(La_Estrella)
Puerto_Triunfo_model = 10 * np.log10(Puerto_Triunfo)
Radar_Vientos_model = 10 * np.log10(Radar_Vientos)
Montañita_SanAntonio_model = 10 * np.log10(Montañita_SanAntonio)
Williams_model = 10 * np.log10(Williams)

plt.figure(figsize=(8, 6))

plt.plot(dm_range, Torre_SIATA_model, label='Torre SIATA', color='blue')
plt.plot(dm_range, P_3_Aguas_model, label='Parque 3 Aguas', color='red')
plt.plot(dm_range, S_Rita_Guatape_model, label='Santa Rita Guatapé', color='green')
plt.plot(dm_range, Samana_model, label='Samaná', color='orange')
plt.plot(dm_range, La_Estrella_model, label='La Estrella', color='purple')
plt.plot(dm_range, Puerto_Triunfo_model, label='Puerto Triunfo', color='brown')
plt.plot(dm_range, Radar_Vientos_model, label='Radar de Vientos', color='cyan')
plt.plot(dm_range, Montañita_SanAntonio_model, label='Montañita San Antonio', color='gray')
plt.plot(dm_range, Williams_model, '^', label='Williams', color='black', alpha=0.2)

plt.xlabel('$D_m\ [mm]$')
plt.ylabel('$R\ [dBR]$')
plt.gca().yaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.gca().xaxis.set_minor_locator(ticker.AutoMinorLocator())
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.ylim(-10, 25)
plt.xlim(0, 5.5)

plt.show()
